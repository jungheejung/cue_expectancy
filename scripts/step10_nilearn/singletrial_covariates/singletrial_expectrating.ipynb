# %%
import numpy as np
import glob
import os
import pathlib
import re
import statsmodels 
from statsmodels.stats import multitest
import scipy
import nilearn
from scipy import stats
from nilearn.image import resample_to_img, math_img
from nilearn import image
from nilearn import plotting
import argparse
from nilearn.image import new_img_like
import matplotlib.pyplot as plt
from os.path import join

# %% [markdown]
# # load and stack images
# conduct t-test
# convert values back to corr values

# %%
main_dir = '/Volumes/spacetop_projects_cue/'
fmri_event = 'stimulus'
nii_flist = glob.glob(join(main_dir, 'analysis', 'fmri', 'nilearn', 'covariate', 'expectrating', f"corr_sub-*_x-stimulus_y-expectrating.nii.gz" ))

# %%
remove_sub = [25, 26, 32, 43, 56, 58, 81, 84, 98, 102, 103, 104, 107, 117]

filtered_file_list = [file_path for file_path in nii_flist if not any(str(num) in file_path for num in remove_sub)]

# %%
len(filtered_file_list)
# Out:
# 82

# %%
filtered_file_list[0:5]
# Out:
# ['/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0047_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0122_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0114_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0094_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0092_x-stimulus_y-expectrating.nii.gz']

# %%
filtered_file_list
# Out:
# ['/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0047_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0122_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0114_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0094_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0092_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0004_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0028_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0036_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0099_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0017_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0118_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0057_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0013_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0109_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0008_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0089_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0083_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0011_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0085_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0131_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0061_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0015_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0079_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0023_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0024_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0051_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0016_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0129_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0119_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0018_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0112_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0052_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0124_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0005_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0097_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0068_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0009_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0091_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0106_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0055_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0064_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0128_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0019_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0059_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0002_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0066_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0037_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0115_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0044_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0123_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0038_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0077_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0021_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0006_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0007_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0073_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0039_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0133_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0116_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0053_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0035_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0093_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0074_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0127_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0111_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0029_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0069_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0076_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0086_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0033_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0078_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0062_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0031_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0101_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0014_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0003_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0087_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0082_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0095_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0063_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0041_x-stimulus_y-expectrating.nii.gz',
#  '/Volumes/spacetop_projects_cue/analysis/fmri/nilearn/covariate/expectrating/corr_sub-0088_x-stimulus_y-expectrating.nii.gz']

# %%
plotting.plot_stat_map(filtered_file_list[0])
# Out:
# /Users/h/miniconda3/envs/spacetop/lib/python3.11/site-packages/nilearn/_utils/niimg.py:62: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   warn(

# %%
concatenated_image = image.concat_imgs(sorted(filtered_file_list))

# %%
concatenated_image.get_fdata().shape
# Out:
# (73, 86, 73, 82)

# %%
mean1 = image.mean_img(filtered_file_list[0])
mean2 = image.mean_img(filtered_file_list[1])
plotting.plot_stat_map(mean1, display_mode='z', cut_coords=3)
plotting.plot_stat_map(mean2, display_mode='z', cut_coords=3)
# Out:
# /Users/h/miniconda3/envs/spacetop/lib/python3.11/site-packages/nilearn/_utils/niimg.py:62: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   warn(

# %% [markdown]
# mean image

# %%
mean_image = image.mean_img(concatenated_image)
plotting.plot_stat_map(mean_image)
# Out:
# /Users/h/miniconda3/envs/spacetop/lib/python3.11/site-packages/nilearn/_utils/niimg.py:62: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   warn(
# /Users/h/miniconda3/envs/spacetop/lib/python3.11/site-packages/nilearn/plotting/find_cuts.py:69: UserWarning: Given img is empty. Returning default cut_coords=(0.0, 0.0, 0.0) instead.
#   warnings.warn(
# /Users/h/miniconda3/envs/spacetop/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:382: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %% [markdown]
# # mask images

# %%
# imgfname = join(main_dir, f'analysis/fmri/nilearn/singletrial/sub-0060/sub-0060_ses-01_run-05_runtype-vicarious_event-{fmri_event}_trial-011_cuetype-low_stimintensity-low.nii.gz')
# ref_img = image.load_img(imgfname)

mask = image.load_img('/Users/h/Documents/MATLAB/CanlabCore/CanlabCore/canlab_canonical_brains/Canonical_brains_surfaces/brainmask_canlab.nii')
first_image = image.index_img(concatenated_image, 0)
mask_img = nilearn.masking.compute_epi_mask(mask, target_affine = first_image.affine, target_shape = first_image.shape)

nifti_masker = nilearn.maskers.NiftiMasker(mask_img= mask_img,
                                           smoothing_fwhm=6,
                            target_affine = first_image.affine, target_shape = first_image.shape, 
                    memory="nilearn_cache", memory_level=1)

# %%
plotting.plot_stat_map(first_image)

# %%
fmri_masked = nifti_masker.fit_transform(concatenated_image)
# Out:
# /Users/h/miniconda3/envs/spacetop/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:542: UserWarning: Persisting input arguments took 0.88s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   data = self._cache(

# %%
fmri_masked.shape
# Out:
# (82, 98053)

# %%
meanval = np.nanmean(fmri_masked, axis = 0)

# %%
meanval.shape
# Out:
# (98053,)

# %%
plt.hist(meanval)
# Out:
# (array([   75.,   786.,  2487.,  8129., 21806., 33905., 22481.,  6856.,
#          1356.,   172.]),
#  array([-0.12982339, -0.10964415, -0.08946492, -0.06928568, -0.04910645,
#         -0.02892722, -0.00874798,  0.01143125,  0.03161048,  0.05178972,
#          0.07196895]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # ttest

# %%
fmri_masked.shape
# Out:
# (82, 98053)

# %%
tvalues, pvalues = scipy.stats.ttest_1samp(fmri_masked, popmean=0,axis=0, alternative='two-sided', nan_policy = 'propagate')
reject, qvalues, _, _ = multitest.multipletests(pvalues, method='fdr_bh')

# %%
# tvalues, pvalues = scipy.stats.ttest_rel(fmri_masked_stimhighp, fmri_masked_stimlowp, axis = 0, nan_policy = 'propagate',alternative='two-sided' )
# reject, qvalues, _, _ = multitest.multipletests(pvalues, method='fdr_bh')
tanhcorr_t = np.tanh(np.nanmean(fmri_masked, axis = 0))
                     
# map 1
con_t = nifti_masker.inverse_transform(tanhcorr_t)

# map 2
result_mapp = np.zeros(fmri_masked.shape[1])
result_mapp[qvalues < .05] = tanhcorr_t[qvalues < .05] #tvalues[qvalues < .05]
con_tmapp = nifti_masker.inverse_transform(result_mapp)

# map 3
result_map_001p = np.zeros(fmri_masked.shape[1])
result_map_001p[qvalues < .001] = tanhcorr_t[qvalues < .001] #tvalues[qvalues < .001]
con_tmap_001p = nifti_masker.inverse_transform(result_map_001p)

plotting.plot_stat_map(con_t,  display_mode = 'mosaic', title = 'task-pain q < .05', cut_coords = 8)
plotting.plot_stat_map(con_tmapp,  display_mode = 'mosaic', title = 'task-pain q < .05', cut_coords = 8)
plotting.plot_stat_map(con_tmap_001p,  display_mode = 'mosaic', title = 'task-pain  q < .001', cut_coords = 8)
