# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import os

# %%
def display_image_in_actual_size(im_path):

    dpi = mpl.rcParams['figure.dpi']
    im_data = plt.imread(im_path)
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
dir_image = '/Users/h/Dropbox/Projects/socialPain/reports/'

# %% [markdown]
# # Design

# %% [markdown]
# * 3 task (2 blocks per task)
# * 6 conditions (HLcue x HLdifficulty)
# * 6 trials per condition
# * 15s per trial
#
# * 3task * 2block * 6cond * 15sec * 6trial = 54 min

# %%
display_image_in_actual_size(dir_image + 'social_influence_design.png')

# %% [markdown]
# ---
#
# # version 1: combined 2 EVs, 2 ISIs
# * EV1 (cue) + EV2 (expect_rating)
# * ISI (0-2s, mean 1s)
# * EV3 (administer_pain) + EV4 (actual_rating)
# * ITI (0-4s, mean 2s)

# %%
fig = plt.figure(figsize=(100, 80)) 
grid = plt.GridSpec(2,3, wspace=0.1, hspace=0.1)

ax0 = plt.subplot(grid[1, :2])
ax1 = plt.subplot(grid[1, 2]);

img_A = mpimg.imread(dir_image + 'ver1_updated.png')
img_B = mpimg.imread(dir_image + 'ver1_updated_predicted.png')

ax0.imshow(img_A);
ax1.imshow(img_B);

# %% [markdown]
# **---**
#
# # Version 2: 4 separate EVs, 2 ISIs
# * EV1 (cue)
# * EV2 (expected rating)
# * ISI (0-2 sec, average 1s)
# * EV3 (administer pain)
# * EV4 (actual rating)
# * ITI (0-4 sec, average 2s)

# %%
fig = plt.figure(figsize=(100, 80)) 
grid = plt.GridSpec(2,3, wspace=0.1, hspace=0.1)

ax0 = plt.subplot(grid[1, :2])
ax1 = plt.subplot(grid[1, 2]);

img_A = mpimg.imread(dir_image + 'ver2_4events_2ISI_vif.png')
img_B = mpimg.imread(dir_image + 'ver2_4events_2ISI_predicted.png')

ax0.imshow(img_A);
ax1.imshow(img_B);
